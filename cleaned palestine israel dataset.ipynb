# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/User/Documents/Uches folder/Palestine Body Count.csv')

# %%
df
# Out:
#        Year      Month Palestinians Injuries Israelis Injuries  \
# 0    2000.0   DECEMBER                   781               NaN
# 1    2000.0   NOVEMBER                  3838               NaN
# 2    2000.0    OCTOBER                  5984               NaN
# 3    2000.0  SEPTEMBER                   NaN               NaN
# 4    2001.0   DECEMBER                   304               NaN
# ..      ...        ...                   ...               ...
# 246  2021.0      MARCH                   NaN               NaN
# 247  2021.0      APRIL                   NaN               NaN
# 248  2021.0        MAY                   NaN               NaN
# 249     NaN        NaN                   NaN               NaN
# 250     NaN        NaN               111,475             5,160
#
#     Palestinians Killed Israelis Killed
# 0                    51               8
# 1                   112              22
# 2                   104              10
# 3                    16               1
# ...

# %%
#displays information about the DataFrame such as number of non-null entries, datatypes and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   249 non-null    float64
#  1   Month                  249 non-null    object
#  2   Palestinians Injuries  196 non-null    object
#  3   Israelis Injuries      133 non-null    object
#  4   Palestinians Killed    250 non-null    object
#  5   Israelis Killed        250 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 11.9+ KB

# %%
df.isnull().sum()
# Out:
# Year                       2
# Month                      2
# Palestinians Injuries     55
# Israelis Injuries        118
# Palestinians Killed        1
# Israelis Killed            1
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Palestinians Injuries', 'Israelis Injuries',
#        'Palestinians Killed', 'Israelis Killed'],
#       dtype='object')

# %%
df.fillna(0,inplace=True)
df
# Out:
#        Year      Month Palestinians Injuries Israelis Injuries  \
# 0    2000.0   DECEMBER                   781                 0
# 1    2000.0   NOVEMBER                  3838                 0
# 2    2000.0    OCTOBER                  5984                 0
# 3    2000.0  SEPTEMBER                     0                 0
# 4    2001.0   DECEMBER                   304                 0
# ..      ...        ...                   ...               ...
# 244  2021.0    JANUARY                     0                 0
# 245  2021.0   FEBRUARY                     0                 0
# 246  2021.0      MARCH                     0                 0
# 247  2021.0      APRIL                     0                 0
# 248  2021.0        MAY                     0                 0
#
#     Palestinians Killed Israelis Killed
# 0                    51               8
# 1                   112              22
# 2                   104              10
# 3                    16               1
# ...

# %%
df['Palestinians Injuries']=df['Palestinians Injuries'].replace("(incl. Jun)",np.nan)
df['Israelis Injuries']=df['Israelis Injuries'].replace("(incl. Jun)",np.nan)
df['Palestinians Injuries']=df['Palestinians Injuries'].replace("(incl. Aug)",np.nan)
df['Israelis Injuries']=df['Israelis Injuries'].replace("(incl. Aug)",np.nan)

# %%
df = df.iloc[0:249]
df
# Out:
#        Year      Month Palestinians Injuries Israelis Injuries  \
# 0    2000.0   DECEMBER                   781                 0
# 1    2000.0   NOVEMBER                  3838                 0
# 2    2000.0    OCTOBER                  5984                 0
# 3    2000.0  SEPTEMBER                     0                 0
# 4    2001.0   DECEMBER                   304                 0
# ..      ...        ...                   ...               ...
# 244  2021.0    JANUARY                     0                 0
# 245  2021.0   FEBRUARY                     0                 0
# 246  2021.0      MARCH                     0                 0
# 247  2021.0      APRIL                     0                 0
# 248  2021.0        MAY                     0                 0
#
#     Palestinians Killed Israelis Killed
# 0                    51               8
# 1                   112              22
# 2                   104              10
# 3                    16               1
# ...

# %%
df=df.astype({'Year':int,'Palestinians Injuries':int,'Israelis Injuries':int,'Palestinians Killed':int,'Israelis Killed':int})
df
# Out:
#      Year      Month  Palestinians Injuries  Israelis Injuries  \
# 0    2000   DECEMBER                    781                  0
# 1    2000   NOVEMBER                   3838                  0
# 2    2000    OCTOBER                   5984                  0
# 3    2000  SEPTEMBER                      0                  0
# 4    2001   DECEMBER                    304                  0
# ..    ...        ...                    ...                ...
# 244  2021    JANUARY                      0                  0
# 245  2021   FEBRUARY                      0                  0
# 246  2021      MARCH                      0                  0
# 247  2021      APRIL                      0                  0
# 248  2021        MAY                      0                  0
#
#      Palestinians Killed  Israelis Killed
# 0                     51                8
# 1                    112               22
# 2                    104               10
# ...

# %%
df["Palestinians Casualties"] = (df["Palestinians Killed"]+ df["Palestinians Injuries"])
df["Israelis Casualties"] = (df["Israelis Killed"]+ df["Israelis Injuries"])
df
# Out:
#      Year      Month  Palestinians Injuries  Israelis Injuries  \
# 0    2000   DECEMBER                    781                  0
# 1    2000   NOVEMBER                   3838                  0
# 2    2000    OCTOBER                   5984                  0
# 3    2000  SEPTEMBER                      0                  0
# 4    2001   DECEMBER                    304                  0
# ..    ...        ...                    ...                ...
# 244  2021    JANUARY                      0                  0
# 245  2021   FEBRUARY                      0                  0
# 246  2021      MARCH                      0                  0
# 247  2021      APRIL                      0                  0
# 248  2021        MAY                      0                  0
#
#      Palestinians Killed  Israelis Killed  Palestinians Casualties  \
# 0                     51                8                      832
# 1                    112               22                     3950
# ...

# %%
# to save it to a dataframe
df.to_csv("palestine_israel.csv", index = False)
